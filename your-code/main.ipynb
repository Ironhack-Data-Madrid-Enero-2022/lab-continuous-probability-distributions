# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!

# %% [markdown]
# In this exercise, we  will generate random numbers from the continuous disributions we learned in the lesson. There are two ways to generate random numbers:
#
# 1. Using the numpy library
# 1. using the Scipy library
#
# Use either or both of the lbraries in this exercise.

# %% [markdown]
# ## Uniform Distribution
#
# To generate uniform random numbers between any two given values using scipy, we can either use the following code or the code that we have
# discussed in class:

# %%
from scipy.stats import uniform

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import pandas as pd

# Matplotlib inline para visualizar los gráficos de Matplotlib
# %matplotlib inline
# %config Inlinebackend.figure_format= 'retina'
#configuracion de matlib
sns.set_context("poster")
sns.set(rc={"figure.figsize": (14.,6.)})
sns.set_style("whitegrid")


x = uniform.rvs(size=10)
a = 2
b = 3
randoms  = a + (b-a)*x
print(randoms)
# Out:
# [2.10429835 2.20738295 2.88888833 2.20325843 2.92688538 2.61007227
#  2.76338415 2.43230794 2.3625921  2.24991901]

# %% [markdown]
# **Your task:**
#
# 1. Based on the code above, write a function that generates uniformly distributed random numbers. There are several requirements for your function:
#     * It should accept 3 parameters:
#         * `bottom` - the lower boundary of the generated numbers
#         * `ceiling` - the upper boundary of the generated numbers
#         * `count` - how many numbers to generate
#     * It should return an array of uniformly distributed random numbers
#
# 1. Call your function with 2 sets of params below:
#     * bottom=10, ceiling=15, count=100
#     * bottom=10, ceiling=60, count=1,000
#
# 1. Plot the uniform distributions generated above using histograms, where x axis is the value and y axis is the count. Let the histogram's number of bins be 10.
#
# Your output should look like below:
#
# ![uniform distribution](ud.png)

# %%
# your code here

def Uniformaly_distr_numbers(bott, ceil, count):
    x = uniform.rvs(size=count)
    randoms  = bott + (ceil-bott)*x
    return randoms
fig, axs = plt.subplots(ncols=2)
sns.histplot(Uniformaly_distr_numbers(10, 15, 100), bins=10, ax=axs[0]); 
sns.histplot(Uniformaly_distr_numbers(10, 60, 1000),bins=10, ax=axs[1]);

# %% [markdown]
# How are the two distributions different?

# %%
# your answer below

'''The forced bins to 10 is providing a more distributed diagram in the count 1000, since it gathers more numbers 
in each of the counts. If we will adjust the bins to have the closest distribution, we would see the real distribution'''

fig, axs = plt.subplots(ncols=2)
sns.histplot(Uniformaly_distr_numbers(10, 15, 100), bins=10, ax=axs[0]); 
sns.histplot(Uniformaly_distr_numbers(10, 60, 1000),bins=100, ax=axs[1]);

# %% [markdown]
# ## Normal Distribution
#
# 1. In the same way in the Uniform Distribution challenge, write a function that generates normally distributed random numbers.
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 1
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 50
# 2. Plot the distributions of the data generated.
#
# Expected output:
#
# ![normal distribution](nd.png)

# %%
# your code here
from scipy.stats import norm

def normal(ave, stdv):
    x = norm(ave,stdv)
    random = x.rvs(size=1000)
    return random


uno = normal(10, 1)
dos = normal(10, 50)


fig, axs = plt.subplots(ncols=2)
sns.histplot(uno, bins=100, kde = True, ax=axs[0]); 
sns.histplot(dos,bins=100, kde = True, ax=axs[1]);

# %% [markdown]
# How are the two distributions different?

# %%
# your answer below
''' The distributions are very similar, since the normal distribution has a simetry distribution'''

# %% [markdown]
# ## Normal Distribution of Real Data
#
# In this challenge we are going to take a look the real data. We will use vehicles.csv file for this exercise

# %% [markdown]
# First import vehicles.csv.
# Then plot the histograms for the following variables:
#
# 1. Fuel Barrels/Year

# %%
vehicles = pd.read_csv('vehicles.csv')
vehicles.sample(2)
# Out:
#           Make        Model  Year  Engine Displacement  Cylinders  \
# 28934  Pontiac  Torrent FWD  2008                  3.4        6.0
# 22940    Mazda         MX-3  1993                  1.9        6.0
#
#           Transmission         Drivetrain                Vehicle Class  \
# 28934  Automatic 5-spd  Front-Wheel Drive  Sport Utility Vehicle - 2WD
# 22940     Manual 5-spd  Front-Wheel Drive              Subcompact Cars
#
#       Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 28934   Regular          17.347895        17           24            19
# 22940   Regular          14.982273        20           26            22
#
#        CO2 Emission Grams/Mile  Fuel Cost/Year
# 28934               467.736842            1750
# 22940               403.954545            1500

# %%
# your code here
sns.histplot(x=vehicles['Fuel Barrels/Year'], kde=True );

# %% [markdown]
# 2. CO2 Emission Grams/Mile

# %%
# your code here
sns.histplot(x=vehicles['CO2 Emission Grams/Mile'], kde = True);

# %% [markdown]
# 3. Combined MPG

# %%
# your code here
sns.histplot(x=vehicles['Combined MPG'], kde = True);

# %% [markdown]
# Which one(s) of the variables are nearly normally distributed? How do you know?

# %%
# your answer here
''' the combined MPG is the most normally distributed, 
since the values are following a trend and has to peaks or valeys on the counts. '''
# Out:
# ' the combined MPG is the most normally distributed, \nsince the values are following a trend and has to peaks or valeys on the counts. '

# %% [markdown]
# ## Exponential Distribution

# %% [markdown]
# 1. Using `numpy.random.exponential`, create a function that returns a list of numbers exponentially distributed with the mean of 10.
#
# 1. Use the function to generate two number sequences with the size of 10 and 100.
#
# 1. Plot the distributions as histograms with the nubmer of bins as 100.
#
# Your output should look like below:
#
# ![exponential distribution](ed.png)

# %%
# your code here
from scipy.stats import expon
exp_np = np.random.exponential(size = 10)
exp_np2 = np.random.exponential(size = 100)


fig, axs = plt.subplots(ncols=2)
sns.histplot(exp_np, bins=50,  ax=axs[0]); 
sns.histplot(exp_np2, bins=50, ax=axs[1]);

# %% [markdown]
# How are the two distributions different?

# %%
# your answer here
''' the exponential distribution is hardly visible with a low exponent, meaning the size of the exponent should be high. 
In the following two pictures we can see with a higher size'''


fig, axs = plt.subplots(ncols=2)
sns.histplot(exp_np2, bins=100, ax=axs[0]);
sns.histplot(np.random.exponential(size = 1000), bins=100, ax=axs[1]);

# %% [markdown]
# ## Exponential Distribution of Real Data
#
# Suppose that the amount of time one spends in a bank is exponentially distributed with mean as 10 minutes (i.e. λ = 1/10). What is the probability that a customer will spend less than fifteen minutes in the bank?
#
# Write a code in python to solve this problem

# %%
# your answer here
# Hint: This is same as saying P(x<15)
exp=expon(scale=10)
muestra=exp.rvs(size=10)

count = 0
for i in muestra:
    if i<15:
        count +=1
print(count/len(muestra))
# Out:
# 0.8

# %% [markdown]
# What is the probability that the customer will spend more than 15 minutes

# %%
# your answer here
''' It varies, but it will be between 0.7 and 0.9'''
# Out:
# ' It varies, but it will be between 0.7 and 0.9'
