# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!

# %% [markdown]
# In this exercise, we  will generate random numbers from the continuous disributions we learned in the lesson. There are two ways to generate random numbers:
#
# 1. Using the numpy library
# 1. using the Scipy library
#
# Use either or both of the lbraries in this exercise.

# %% [markdown]
# ## Uniform Distribution
#
# To generate uniform random numbers between any two given values using scipy, we can either use the following code or the code that we have
# discussed in class:

# %%
from scipy.stats import uniform
import seaborn as sns
import pylab as plt

x = uniform.rvs(size=10)
a = 2
b = 3
randoms  = a + (b-a)*x
print(randoms)
# Out:
# [2.30550718 2.50674028 2.92603926 2.13526837 2.17546993 2.45170334
#  2.39774656 2.77994332 2.05848059 2.4119426 ]

# %% [markdown]
# **Your task:**
#
# 1. Based on the code above, write a function that generates uniformly distributed random numbers. There are several requirements for your function:
#     * It should accept 3 parameters:
#         * `bottom` - the lower boundary of the generated numbers
#         * `ceiling` - the upper boundary of the generated numbers
#         * `count` - how many numbers to generate
#     * It should return an array of uniformly distributed random numbers
#
# 1. Call your function with 2 sets of params below:
#     * bottom=10, ceiling=15, count=100
#     * bottom=10, ceiling=60, count=1,000
#
# 1. Plot the uniform distributions generated above using histograms, where x axis is the value and y axis is the count. Let the histogram's number of bins be 10.
#
# Your output should look like below:
#
# ![uniform distribution](ud.png)

# %%
# your code here
def random_uniform(b, c, n):
    return b+(c-b)*uniform.rvs(size=n)

fig, axes = plt.subplots(1,2, sharey=True)

bottom,ceiling,count=10,15,100

data = random_uniform(bottom, ceiling, count)

sns.histplot(ax=axes[0], x = data)

bottom, ceiling, count=10,60,1000

random_uniform(bottom, ceiling, count)

sns.histplot(ax = axes[1], x = random_uniform(bottom, ceiling, count))
plt.show()

# %% [markdown]
# How are the two distributions different?

# %%
# your answer below
"""The bigger the sample is, the better to observe a uniform distribution, also the size of the range affects that distribution, 
as the data is going to be more or less spread among the range, that can be observe by any range if we change the binsize."""

# %% [markdown]
# ## Normal Distribution
#
# 1. In the same way in the Uniform Distribution challenge, write a function that generates normally distributed random numbers.
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 1
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 50
# 2. Plot the distributions of the data generated.
#
# Expected output:
#
# ![normal distribution](nd.png)

# %% [markdown]
# $$f(x)= P(x) = \frac{1}{\sigma\sqrt{2\pi}}
#   \exp\left( -\frac{1}{2}\left(\frac{x-\mu}{\sigma}\right)^{\!2}\,\right)$$

# %%
import math
from scipy.stats import norm

# %%
# your code here
fig, axes = plt.subplots(1,2, sharey=True)
mu, sig, n = 10, 10, 1000

sns.histplot(ax=axes[0], x = norm(mu,sig).rvs(size=n))

mu, sig, n = 10, 50, 1000

sns.histplot(ax=axes[1], x = norm(mu,sig).rvs(size=n))

plt.show()

# %% [markdown]
# How are the two distributions different?

# %%
# your answer below
""" They are both centred on 10, but the dispersion around ten in one case is quite small (the probabiity of finding a number larger than 40 or smaller than -30is almost 0 ),
whereas in the other case we can easly find numbers above 50."""

# %% [markdown]
# ## Normal Distribution of Real Data
#
# In this challenge we are going to take a look the real data. We will use vehicles.csv file for this exercise

# %% [markdown]
# First import vehicles.csv.
# Then plot the histograms for the following variables:
#
# 1. Fuel Barrels/Year

# %%
import pandas as pd
# your code here
df = pd.read_csv('vehicles.csv')
sns.histplot(x = df['Fuel Barrels/Year'])
plt.show()
df.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Displacement', 'Cylinders',
#        'Transmission', 'Drivetrain', 'Vehicle Class', 'Fuel Type',
#        'Fuel Barrels/Year', 'City MPG', 'Highway MPG', 'Combined MPG',
#        'CO2 Emission Grams/Mile', 'Fuel Cost/Year'],
#       dtype='object')

# %%
a = norm.stats(loc=df['Fuel Barrels/Year'].mean(),
           scale=df['Fuel Barrels/Year'].std(),moments='mvsk')
print(f"Media:{a[0]:.2f}, Moda:{a[1]:.2f}, Sim:{a[2]:.2f}, Kurt:{a[3]:.2f}")
# Out:
# Media:17.61, Moda:19.96, Sim:0.00, Kurt:0.00

# %% [markdown]
# 2. CO2 Emission Grams/Mile

# %%
# your code here
sns.histplot(x = df['CO2 Emission Grams/Mile'])
plt.show()
a = norm.stats(loc=df['CO2 Emission Grams/Mile'].mean(),
           scale=df['CO2 Emission Grams/Mile'].std(),moments='mvsk')
print(f"Media:{a[0]:.2f}, Moda:{a[1]:.2f}, Sim:{a[2]:.2f}, Kurt:{a[3]:.2f}")
# Out:
# Media:475.32, Moda:14175.47, Sim:0.00, Kurt:0.00

# %% [markdown]
# 3. Combined MPG

# %%
# your code here
sns.histplot(x = df['Combined MPG'])
plt.show()
a = norm.stats(loc=df['Combined MPG'].mean(),
           scale=df['Combined MPG'].std(),moments='mvsk')
print(f"Media:{a[0]:.2f}, Moda:{a[1]:.2f}, Sim:{a[2]:.2f}, Kurt:{a[3]:.2f}")
# Out:
# Media:19.93, Moda:26.14, Sim:0.00, Kurt:0.00

# %% [markdown]
# Which one(s) of the variables are nearly normally distributed? How do you know?

# %%
# your answer here
""" They all look like a normal distribution, they all have 0 simetry and kurt. I think the last one is the more nearly normally distributed."""
# Out:
# ' They all look like a normal distribution, they all have 0 simetry and kurt. I think the last one is the more nearly normally distributed.'

# %% [markdown]
# ## Exponential Distribution

# %% [markdown]
# 1. Using `numpy.random.exponential`, create a function that returns a list of numbers exponentially distributed with the mean of 10.
#
# 1. Use the function to generate two number sequences with the size of 10 and 100.
#
# 1. Plot the distributions as histograms with the nubmer of bins as 100.
#
# Your output should look like below:
#
# ![exponential distribution](ed.png)

# %%
# your code here
from numpy import random
import numpy as np
def exponential_dist(n):
    lst = []
    for i in range(n): lst.append(random.exponential(10))
    return lst

a = exponential_dist(110)
b = exponential_dist(100)

# your code here
fig, axes = plt.subplots(1,2)

sns.histplot(ax=axes[0], x = a, bins= 100)


sns.histplot(ax=axes[1], x = b, bins= 100)

plt.show()

# %% [markdown]
# How are the two distributions different?

# %%
# your answer here
""" I have done it with a bigger sample as with just 10 numbers it is not enough to observe the distribution. The bigger the sample the better 
we observe it."""

# %% [markdown]
# ## Exponential Distribution of Real Data
#
# Suppose that the amount of time one spends in a bank is exponentially distributed with mean as 10 minutes (i.e. λ = 1/10). What is the probability that a customer will spend less than fifteen minutes in the bank?
#
# Write a code in python to solve this problem

# %%
# your answer here
# Hint: This is same as saying P(x<15)
from scipy.stats import expon
exp=expon(scale=10)
print(f'{exp.cdf(15):.2f}')
# Out:
# 0.78

# %% [markdown]
# What is the probability that the customer will spend more than 15 minutes

# %%
# your answer here
print(f'{1-exp.cdf(15):.2f}')
# Out:
# 0.22
